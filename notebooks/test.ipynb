# %%
import yfinance as yf

#example = yf.download('005930.KS', period="1y", interval="1d")

stock = yf.Ticker('005930.KS')
example = stock.history(
    start='2025-12-10',
    end='2025-12-20',
)
print(example.head(20))

print(example.index.tz)

example = example.reset_index()
print(example.columns)
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2025-12-10 00:00:00+09:00  108300.0  109800.0  107400.0  108000.0  12365092
# 2025-12-11 00:00:00+09:00  109200.0  110500.0  107300.0  107300.0  22994507
# 2025-12-12 00:00:00+09:00  107100.0  108900.0  106800.0  108900.0  14210314
# 2025-12-15 00:00:00+09:00  105300.0  105800.0  104600.0  104800.0  20594654
# 2025-12-16 00:00:00+09:00  104900.0  105600.0  102700.0  102800.0  18852079
# 2025-12-17 00:00:00+09:00  103500.0  108100.0  103400.0  107900.0  22297611
# 2025-12-18 00:00:00+09:00  106400.0  108200.0  105700.0  107600.0  20445631
# 2025-12-19 00:00:00+09:00  109700.0  109700.0  106200.0  106300.0  25917098
#
#                            Dividends  Stock Splits
# Date
# 2025-12-10 00:00:00+09:00        0.0           0.0
# 2025-12-11 00:00:00+09:00        0.0           0.0
# 2025-12-12 00:00:00+09:00        0.0           0.0
# 2025-12-15 00:00:00+09:00        0.0           0.0
# ...
